# %%
using Test
using StaticArrays
using Random
using Plots
import Pkg
using Statistics

import Pkg
Pkg.activate("/Users/mckinleypaul/Documents/montecarlo/segc_wl")
using segc_wl   # or the module name inside segc_wl.jl
include("/Users/mckinleypaul/Documents/montecarlo/segc_wl/test/hyper_parameter_tuning/analysis.jl")
# Out:
#   Activating project at `~/Documents/montecarlo/segc_wl`

# %%
percents = [1,5,100] # 100 = control
λ_rates = [36,37,37,]
translation_rates = [40,38,33]
maxima = [60480,53029,53152]
#means all 9901 lol 
std_devs = [16374.0,16067.0,15857.0,]
coeff_var = [1.6015999879348983, 1.6227451826499657, 1.6015999879348983]
highest_N_at_1000 = [436, 436,437]
scatter(percents,maxima,xlabel= "%N δr max computed with",ylabel = "maximum")
display(plot!(percents,maxima))

scatter(percents,coeff_var, xlabel= "%N δr max computed with",ylabel = "coefficient of variance")
plot!(percents,coeff_var)

# scatter(percents,std_devs, xlabel= "Percent fractional particle moves",ylabel = "std devs")
# plot!(percents,std_devs)

# %%
prerun_1 = load_wanglandau_jld2("/Users/mckinleypaul/Documents/montecarlo/segc_wl/test/hyper_parameter_tuning/desgranges_potential/fixed_delta_r_max/1/prerun_for_delta_r/final_wl.jld2")
println(prerun_1.δr_max_box) # using this parameter for other simulation
# Out:
# 0.004782007344188789

# %%
prerun_5 = load_wanglandau_jld2("/Users/mckinleypaul/Documents/montecarlo/segc_wl/test/hyper_parameter_tuning/desgranges_potential/fixed_delta_r_max/5/prerun_for_delta_r/final_wl.jld2")
println(prerun_5.δr_max_box) # using this parameter for other simulation
# Out:
# 0.0068392821378580005

# %%
wl_control = load_wanglandau_jld2("/Users/mckinleypaul/Documents/montecarlo/segc_wl/test/hyper_parameter_tuning/control/final_wl.jld2")
bashout_control = "/Users/mckinleypaul/Documents/montecarlo/segc_wl/test/hyper_parameter_tuning/control/bashoutput.txt"
analyze_experiment(wl_control,bashout_control)
# Out:
# wl.logf: 1.0
# Runtime: 301 seconds
# λ move acceptance rate: 37.0 %
# Translation move acceptance rate: 33.0 %
# Minimum of all rows and columns from 401 to 500 (expect min=1):1
# Minimum of all rows and columns from 401 to 501 (expect min=0 but higher better):0
# Maximum: 53152
# Mean of histogram is: 9901.0
# Standard Deviation of histogram is: 15857.0
# Coefficient of variation, σ/|μ| = 1.6015999879348983
# σ/|μ| = 0 is perfectly flat, σ/|μ|=0.05 has some structure and σ/|μ|=0.1 is definitely not flat
# The last state sampled at least a thousand times was (N,λ) = (437,99) with histogram value: 1445

# %%
wl_1 = load_wanglandau_jld2("/Users/mckinleypaul/Documents/montecarlo/segc_wl/test/hyper_parameter_tuning/desgranges_potential/fixed_delta_r_max/1/final_wl.jld2")
bashout_1 = "/Users/mckinleypaul/Documents/montecarlo/segc_wl/test/hyper_parameter_tuning/desgranges_potential/fixed_delta_r_max/1/bashoutput.txt"
analyze_experiment(wl_1,bashout_1)
# Out:
# wl.logf: 1.0
# Runtime: 316 seconds
# λ move acceptance rate: 36.0 %
# Translation move acceptance rate: 40.0 %
# Minimum of all rows and columns from 401 to 500 (expect min=1):1
# Minimum of all rows and columns from 401 to 501 (expect min=0 but higher better):0
# Maximum: 60480
# Mean of histogram is: 9901.0
# Standard Deviation of histogram is: 16374.0
# Coefficient of variation, σ/|μ| = 1.65377243975043
# σ/|μ| = 0 is perfectly flat, σ/|μ|=0.05 has some structure and σ/|μ|=0.1 is definitely not flat
# The last state sampled at least a thousand times was (N,λ) = (436,99) with histogram value: 1662

# %%
wl_5 = load_wanglandau_jld2("/Users/mckinleypaul/Documents/montecarlo/segc_wl/test/hyper_parameter_tuning/desgranges_potential/fixed_delta_r_max/5/final_wl.jld2")
bashout_5 = "/Users/mckinleypaul/Documents/montecarlo/segc_wl/test/hyper_parameter_tuning/desgranges_potential/fixed_delta_r_max/5/bashoutput.txt"
analyze_experiment(wl_5,bashout_5)
# Out:
# wl.logf: 1.0
# Runtime: 317 seconds
# λ move acceptance rate: 37.0 %
# Translation move acceptance rate: 38.0 %
# Minimum of all rows and columns from 401 to 500 (expect min=1):1
# Minimum of all rows and columns from 401 to 501 (expect min=0 but higher better):0
# Maximum: 53029
# Mean of histogram is: 9901.0
# Standard Deviation of histogram is: 16067.0
# Coefficient of variation, σ/|μ| = 1.6227451826499657
# σ/|μ| = 0 is perfectly flat, σ/|μ|=0.05 has some structure and σ/|μ|=0.1 is definitely not flat
# The last state sampled at least a thousand times was (N,λ) = (436,99) with histogram value: 2296
