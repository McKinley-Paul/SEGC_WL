# %%
using Test
using StaticArrays
using Random
using Plots
import Pkg
using Statistics

import Pkg
Pkg.activate("/Users/mckinleypaul/Documents/montecarlo/segc_wl")
using segc_wl   # or the module name inside segc_wl.jl

Pkg.activate("/Users/mckinleypaul/Documents/montecarlo/segc_wl")
include("/Users/mckinleypaul/Documents/montecarlo/segc_wl/test/hyper_parameter_tuning/analysis.jl")
# Out:
#   Activating project at `~/Documents/montecarlo/segc_wl`
#   Activating project at `~/Documents/montecarlo/segc_wl`
# analyze_experiment (generic function with 1 method)

# %% [markdown]
# well really no significant differences but the LAMMPS soft core does finish faster - 270 seconds vs 300 for Desgranges
#
# repeatable in two trials for each

# %%
percents = [0,1,2] # just labels here 0 = control, 1 is lammps potential, 2 is hybrid
λ_rates = [37,37.0,37]
translation_rates = [33.0,33,35]
maxima = [53152,51881,54573]
#means all 9901 lol 
std_devs = [15857.0,15703.0,15976.0]
coeff_var = [1.6015999879348983,1.5860170254105816 ,1.6135946536666679
]
highest_N_at_1000 = [437,438,437 ]
scatter(percents,highest_N_at_1000,xlabel= "Label",ylabel = "highest_N_at_1000")
display(plot!(percents,highest_N_at_1000))

scatter(percents,coeff_var, xlabel= "Label",ylabel = "coefficient of variance")
plot!(percents,coeff_var)

# scatter(percents,std_devs, xlabel= "Percent fractional particle moves",ylabel = "std devs")
# plot!(percents,std_devs)

# %%
wl_control = load_wanglandau_jld2("/Users/mckinleypaul/Documents/montecarlo/segc_wl/test/hyper_parameter_tuning/control/final_wl.jld2")
bashout_control = "/Users/mckinleypaul/Documents/montecarlo/segc_wl/test/hyper_parameter_tuning/control/bashoutput.txt"
analyze_experiment(wl_control,bashout_control)
# Out:
# wl.logf: 1.0
# Runtime: 301 seconds
# λ move acceptance rate: 37.0 %
# Translation move acceptance rate: 33.0 %
# Minimum of all rows and columns from 401 to 500 (expect min=1):1
# Minimum of all rows and columns from 401 to 501 (expect min=0 but higher better):0
# Maximum: 53152
# Mean of histogram is: 9901.0
# Standard Deviation of histogram is: 15857.0
# Coefficient of variation, σ/|μ| = 1.6015999879348983
# σ/|μ| = 0 is perfectly flat, σ/|μ|=0.05 has some structure and σ/|μ|=0.1 is definitely not flat
# The last state sampled at least a thousand times was (N,λ) = (437,99) with histogram value: 1445

# %%
wl_lammps = load_wanglandau_jld2("/Users/mckinleypaul/Documents/montecarlo/segc_wl/test/hyper_parameter_tuning/soft_core_potentials/lammps/final_wl.jld2")
bashout_lammps = "/Users/mckinleypaul/Documents/montecarlo/segc_wl/test/hyper_parameter_tuning/soft_core_potentials/lammps/bashoutput.txt"
analyze_experiment(wl_lammps,bashout_lammps)
# Out:
# wl.logf: 1.0
# Runtime: 273 seconds
# λ move acceptance rate: 37.0 %
# Translation move acceptance rate: 33.0 %
# Minimum of all rows and columns from 401 to 500 (expect min=1):1
# Minimum of all rows and columns from 401 to 501 (expect min=0 but higher better):0
# Maximum: 51881
# Mean of histogram is: 9901.0
# Standard Deviation of histogram is: 15703.0
# Coefficient of variation, σ/|μ| = 1.5860170254105816
# σ/|μ| = 0 is perfectly flat, σ/|μ|=0.05 has some structure and σ/|μ|=0.1 is definitely not flat
# The last state sampled at least a thousand times was (N,λ) = (438,99) with histogram value: 2219

# %%
wl_hybrid= load_wanglandau_jld2("/Users/mckinleypaul/Documents/montecarlo/segc_wl/test/hyper_parameter_tuning/soft_core_potentials/lammps_desgranges_hybrid/final_wl.jld2")
bashout_hybrid = "/Users/mckinleypaul/Documents/montecarlo/segc_wl/test/hyper_parameter_tuning/soft_core_potentials/lammps_desgranges_hybrid/bashoutput.txt"
analyze_experiment(wl_hybrid,bashout_hybrid)
# Out:
# wl.logf: 1.0
# Runtime: 320 seconds
# λ move acceptance rate: 37.0 %
# Translation move acceptance rate: 35.0 %
# Minimum of all rows and columns from 401 to 500 (expect min=1):1
# Minimum of all rows and columns from 401 to 501 (expect min=0 but higher better):0
# Maximum: 54573
# Mean of histogram is: 9901.0
# Standard Deviation of histogram is: 15976.0
# Coefficient of variation, σ/|μ| = 1.6135946536666679
# σ/|μ| = 0 is perfectly flat, σ/|μ|=0.05 has some structure and σ/|μ|=0.1 is definitely not flat
# The last state sampled at least a thousand times was (N,λ) = (437,99) with histogram value: 1046
