# %% [markdown]
# # Let this N=500 simulation run for ~17h 5 min too

# %%
using Test
using StaticArrays
using Random
using Plots
import Pkg
using Statistics

Pkg.activate(joinpath(@__DIR__, "../../../"))
using segc_wl   # or the module name inside segc_wl.jl
# Out:
#   Activating project at `~/Documents/montecarlo/segc_wl`

# %%
# input_path = joinpath(@__DIR__, "wl_checkpoin.jdl2")

wl = load_wanglandau_jld2("")
# Out:
# ArgumentError: No file exists at given path:
#
#
#
# Stacktrace:
#
#  [1] checkpath_load
#
#    @ ~/.julia/packages/FileIO/EI2b8/src/loadsave.jl:167 [inlined]
#
#  [2] load(file::String, args::String; options::@Kwargs{})
#
#    @ FileIO ~/.julia/packages/FileIO/EI2b8/src/loadsave.jl:110
#
#  [3] load
#
#    @ ~/.julia/packages/FileIO/EI2b8/src/loadsave.jl:109 [inlined]
#
#  [4] load_wanglandau_jld2(filename::String)
#
#    @ segc_wl ~/Documents/montecarlo/segc_wl/src/initialization.jl:279
#
#  [5] top-level scope
#
#    @ ~/Documents/montecarlo/segc_wl/test/lambda_max_opt/N500_M10_NMin_366 copy/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W2sZmlsZQ==.jl:3

# %%
wl.logf
# Out:
# UndefVarError: `wl` not defined in `Main`
#
# Suggestion: add an appropriate import or assignment. This global was declared but not assigned.
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/Documents/montecarlo/segc_wl/test/lambda_max_opt/N500_M10_NMin_366 copy/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W3sZmlsZQ==.jl:1

# %%
println(minimum(wl.H_λN)) # hasnt even visited all states
println(maximum(wl.H_λN))
# Out:
# UndefVarError: `wl` not defined in `Main`
#
# Suggestion: add an appropriate import or assignment. This global was declared but not assigned.
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/Documents/montecarlo/segc_wl/test/lambda_max_opt/N500_M10_NMin_366 copy/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W4sZmlsZQ==.jl:1

# %%
# Example array (remove this if you already have A)
# A = rand(10, 501)
A = wl.H_λN
# -------------------------
# 1. Average of columns vs column index
# -------------------------
col_avg = mean(A, dims=1)[:]      # size: 501
col_idx = 1:size(A, 2)

p1 = plot(
    col_idx,
    col_avg,
    xlabel = "Column number",
    ylabel = "Average value",
    title = "Column-wise average",
    legend = false
)

# -------------------------
# 2. Average of rows vs row index
# -------------------------
row_avg = mean(A, dims=2)[:]      # size: 10
row_idx = 1:size(A, 1)

p2 = plot(
    row_idx,
    row_avg,
    xlabel = "Row number",
    ylabel = "Average value",
    title = "Row-wise average",
    legend = false
)

# -------------------------
# 3. 3D plot: row, column → value
# -------------------------
rows = 1:size(A, 1)
cols = 1:size(A, 2)

p3 = surface(
    cols,
    rows,
    A,
    xlabel = "Column",
    ylabel = "Row",
    zlabel = "Value",
    title = "3D surface of A"
)

# -------------------------
# Display all three
# -------------------------
plot(p1)
# Out:
# UndefVarError: `wl` not defined in `Main`
#
# Suggestion: add an appropriate import or assignment. This global was declared but not assigned.
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/Documents/montecarlo/segc_wl/test/lambda_max_opt/N500_M10_NMin_366 copy/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W5sZmlsZQ==.jl:5

# %%
plot(p2)
# Out:
# UndefVarError: `p2` not defined in `Main`
#
# Suggestion: check for spelling errors or missing imports.
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/Documents/montecarlo/segc_wl/test/lambda_max_opt/N500_M10_NMin_366 copy/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W6sZmlsZQ==.jl:1

# %%
plot(p3)
# Out:
# UndefVarError: `p3` not defined in `Main`
#
# Suggestion: check for spelling errors or missing imports.
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/Documents/montecarlo/segc_wl/test/lambda_max_opt/N500_M10_NMin_366 copy/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X10sZmlsZQ==.jl:1

# %%
using Statistics
using Plots

# -------------------------
# Column averages (log y)
# -------------------------
col_avg = mean(A, dims=1)[:]
col_idx = 1:size(A, 2)

p1 = plot(
    col_idx,
    col_avg,
    xlabel = "Column number",
    ylabel = "Average value",
    yscale = :log10,
    title = "Column-wise average (log scale)",
    legend = false
)

# -------------------------
# Row averages (log y)
# -------------------------
row_avg = mean(A, dims=2)[:]
row_idx = 1:size(A, 1)

p2 = plot(
    row_idx,
    row_avg,
    xlabel = "Row number",
    ylabel = "Average value",
    yscale = :log10,
    title = "Row-wise average (log scale)",
    legend = false
)

# -------------------------
# 3D surface (linear)
# -------------------------
rows = 1:size(A, 1)
cols = 1:size(A, 2)

p3 = surface(
    cols,
    rows,
    A,
    xlabel = "Column",
    ylabel = "Row",
    zlabel = "Value",
    title = "3D surface of A"
)

plot(p1, p2, p3, layout = (3, 1))
# Out:
# UndefVarError: `A` not defined in `Main`
#
# Suggestion: add an appropriate import or assignment. This global was declared but not assigned.
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/Documents/montecarlo/segc_wl/test/lambda_max_opt/N500_M10_NMin_366 copy/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X11sZmlsZQ==.jl:7

# %%
p1 = plot(
    col_idx,
    col_avg,
    xlabel = "Column number",
    ylabel = "Average value",
    yscale = :log10,
   ylims = (0,100000000000),
    xlims = (365,400),
    title = "Column-wise average (log scale)",
    legend = false, 
    xticks = 360:1:400,
    size = (1200, 300)
)
plot(p1)
# Out:
# UndefVarError: `col_idx` not defined in `Main`
#
# Suggestion: check for spelling errors or missing imports.
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/Documents/montecarlo/segc_wl/test/lambda_max_opt/N500_M10_NMin_366 copy/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X12sZmlsZQ==.jl:1
